# %% [markdown]
# # PIMA INDIANS DIABETES - CLASSIFICATION

# %% [markdown]
# ## Version 1 - Baseline Model

# %% [markdown]
# ### Khai báo thư viện

# %%
import os
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix

# %% [markdown]
# ## 1. Nạp dữ liệu
# - Gán tên cột: Vì tệp dữ liệu gốc thường không có tiêu đề, mã nguồn định nghĩa lại danh sách col_names để các cột như Glucose, BMI, Age... có tên rõ ràng.
#
# - pd.read_csv: Đọc dữ liệu từ file vào biến df (DataFrame) để bắt đầu thao tác.

# %%
data_path = os.path.join(os.getcwd(), "..", "data", "pima-indians-diabetes.csv")
col_names = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI","DiabetesPedigreeFunction", "Age", "Outcome"]

df = pd.read_csv(data_path, header=None, names=col_names)
print(f"Đã nạp {len(df)} dòng dữ liệu.")
print(f"Shape: {df.shape}")
df.head(10)
# Out:
# Đã nạp 768 dòng dữ liệu.
# Shape: (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %%
# các cột có giá trị 0 không hợp lệ
cols = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']

# replace 0 → NaN
df[cols] = df[cols].replace(0, np.nan)

# fill NaN bằng median
df[cols] = df[cols].fillna(df[cols].median())

# kiểm tra lại
print(df.isna().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## 2. Chia tập dữ liệu (Split Data)

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42
)

# %% [markdown]
# ## 3. Huấn luyện mô hình Baseline (Logistic Regression)

# %%
model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## 4. Đánh giá chi tiết
# - model.fit: Đây là bước "máy học", thuật toán Logistic Regression sẽ tìm mối liên hệ giữa các chỉ số y tế và nguy cơ mắc bệnh.
#
# - model.predict: Sau khi học xong, mô hình sẽ dự đoán kết quả cho tập dữ liệu Test (những người mà nó chưa từng thấy qua).
#
# - Kết quả (Metrics):
#
#   - Accuracy: Độ chính xác tổng thể.
#
#   - F1 Score: Thước đo cân bằng giữa việc bỏ sót người bệnh và việc chẩn đoán nhầm người khỏe thành bệnh.
#
#   - Confusion Matrix: Biểu đồ cho thấy cụ thể mô hình đoán đúng bao nhiêu ca và đoán sai ở những vị trí nào.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["No Diabetes", "Diabetes"],
                yticklabels=["No Diabetes", "Diabetes"])

    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()

# %%
y_pred = model.predict(X_test)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("=== BASELINE RESULTS ===")
print(f"Accuracy: {acc:.3f}")
print(f"F1 Score: {f1:.3f}")

print("\nClassification Report:")
report = classification_report(y_test, y_pred, target_names=["No Diabetes", "Diabetes"])
df_report = pd.DataFrame(classification_report(y_test, y_pred, target_names=["No Diabetes", "Diabetes"], output_dict=True)).transpose()
df_report = df_report.round(3)
display(df_report)

print("\nConfusion Matrix:")
plot_confusion_matrix(y_test, y_pred)
# Out:
# === BASELINE RESULTS ===
# Accuracy: 0.740
# F1 Score: 0.610
#
# Classification Report:
#               precision  recall  f1-score  support
# No Diabetes       0.790   0.821     0.805   151.00
# Diabetes          0.635   0.588     0.610    80.00
# accuracy          0.740   0.740     0.740     0.74
# macro avg         0.712   0.704     0.708   231.00
# weighted avg      0.736   0.740     0.738   231.00
# Confusion Matrix:

# %%
# Dùng ".." để nhảy ra ngoài thư mục "proj" và tìm thư mục "exps"
data_dir = os.path.join("..", "exps", "data")
os.makedirs(data_dir, exist_ok=True)

# Lưu lại toàn bộ DataFrame này để làm mốc đối chiếu
file_path = os.path.join(data_dir, "v1_baseline.csv")

# Lưu file
df.to_csv(file_path, index=False)

# %% [markdown]
# ### Tổng kết Version 1:
# - Mô hình: Logistic Regression (mặc định).
#
# - Tiền xử lý: Đã xử lý giá trị 0 thủ công bằng median nhưng chưa chuẩn hóa (Scaling).
#
# - Kết quả: Đây là mốc điểm tựa (Baseline) để so sánh với các cải tiến tiếp theo
